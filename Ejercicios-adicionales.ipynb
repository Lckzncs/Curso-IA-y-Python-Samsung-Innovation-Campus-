# %% [markdown]
# # Ejercicios generales de práctica
#
# Ejercicios adicionales para practicar de cara a la primera prueba de evaluación.
#
# Los ejercicios mezclan contenidos vistos hasta el bucle `while`: impresión por pantalla, expresiones, tipos, cadenas, variables, entrada por teclado, comparaciones, condicionales, `for`, listas y `while`.
#
# Indicaciones:
#
# - Resuelve cada ejercicio en la celda de código situada debajo del enunciado.
# - No utilices partes de Python que no se hayan visto en clase.
# - No utilices `break` ni `continue`.
# - No utilices `return` dentro de un bucle.

# %% [markdown]
# ## Ejercicio 1
#
# Escribe un programa que lea el nombre, la edad y la ciudad de una persona, y muestre una ficha con este formato:
#
# ```text
# nombre: Laura
# edad: 22
# ciudad: Málaga
# --- ficha creada ---
# ```

# %% [markdown]
# ## Ejercicio 2
#
# Escribe un programa que lea una distancia en metros y un tiempo en segundos. El programa debe calcular:
#
# - la distancia en kilómetros
# - el tiempo en minutos
# - la velocidad media en metros por segundo
#
# Ejemplo:
#
# ```text
# distancia en metros: 1500
# tiempo en segundos: 300
# kilómetros: 1.5
# minutos: 5.0
# velocidad media: 5.0
# ```

# %% [markdown]
# ## Ejercicio 3
#
# Un grupo de estudiantes quiere repartir caramelos en bolsas. Escribe un programa que lea cuántos caramelos hay y cuántos caramelos caben en cada bolsa. El programa debe mostrar cuántas bolsas completas se pueden llenar y cuántos caramelos sobran.
#
# Ejemplo:
#
# ```text
# caramelos: 53
# caramelos por bolsa: 8
# bolsas completas: 6
# caramelos sobrantes: 5
# ```

# %% [markdown]
# ## Ejercicio 4
#
# Dada una palabra leída por teclado, muestra:
#
# - su longitud
# - su primer carácter
# - su último carácter usando índice negativo
# - el resultado de repetirla 3 veces
#
# Puedes suponer que la palabra tendrá al menos un carácter.

# %% [markdown]
# ## Ejercicio 5
#
# Escribe un programa que lea un código de producto con el formato `A123Z`, es decir, cinco caracteres. El programa debe mostrar:
#
# - el primer carácter
# - el último carácter
# - los tres caracteres centrales concatenados
#
# Ejemplo:
#
# ```text
# código: B728K
# inicial: B
# final: K
# centro: 728
# ```

# %% [markdown]
# ## Ejercicio 6
#
# Escribe un programa que lea una contraseña y muestre tres valores booleanos:
#
# - si tiene al menos 8 caracteres
# - si contiene el carácter `@`
# - si no contiene espacios
#
# Ejemplo:
#
# ```text
# contraseña: curso@python
# longitud correcta: True
# contiene @: True
# sin espacios: True
# ```

# %% [markdown]
# ## Ejercicio 7
#
# Escribe un programa que lea una temperatura en grados Celsius y la velocidad del viento en km/h. El programa debe mostrar una categoría de temperatura:
#
# - menor que `0`: `helada`
# - entre `0` y `15`, ambos incluidos: `fría`
# - mayor que `15` y menor que `30`: `templada`
# - mayor o igual que `30`: `calurosa`
#
# Además, debe mostrar un aviso adicional:
#
# - si la temperatura es menor que `5` y el viento es mayor que `30`, muestra `aviso: sensación de frío intenso`
# - si la temperatura es mayor o igual que `30` y el viento es menor que `10`, muestra `aviso: calor sofocante`
# - en cualquier otro caso, muestra `aviso: sin riesgo especial`
#
# Ejemplo:
#
# ```text
# temperatura: 2
# viento: 35
# categoría: fría
# aviso: sensación de frío intenso
# ```

# %% [markdown]
# ## Ejercicio 8
#
# Escribe un programa que lea una hora en formato de 24 horas, usando dos enteros: `hora` y `minuto`. El programa debe indicar si la hora es válida.
#
# Una hora es válida si:
#
# - `hora` está entre `0` y `23`
# - `minuto` está entre `0` y `59`
#
# Si la hora es válida, el programa debe mostrar también:
#
# - cuántos minutos han pasado desde medianoche
# - el tramo del día: `madrugada` (`0` a `5`), `mañana` (`6` a `11`), `tarde` (`12` a `19`) o `noche` (`20` a `23`)
#
# Ejemplo:
#
# ```text
# hora: 14
# minuto: 30
# hora válida: True
# minutos desde medianoche: 870
# tramo: tarde
# ```

# %% [markdown]
# ## Ejercicio 9
#
# Escribe un programa que lea tres números enteros. El programa debe mostrar:
#
# - el mayor
# - el menor
# - si los tres números son iguales
# - si hay exactamente dos números iguales
# - si los tres números son distintos
#
# No puedes suponer que los números sean distintos.
#
# Ejemplo:
#
# ```text
# primer número: 8
# segundo número: 3
# tercer número: 8
# mayor: 8
# menor: 3
# exactamente dos iguales: True
# ```

# %% [markdown]
# ## Ejercicio 10
#
# Escribe un programa que lea una nota de teoría, una nota de práctica y un porcentaje de asistencia. La nota final se calcula así:
#
# ```text
# final = teoría * 0.4 + práctica * 0.6
# ```
#
# La asignatura está aprobada solo si se cumplen todas estas condiciones:
#
# - la nota final es mayor o igual que `5`
# - la nota de práctica es mayor o igual que `4`
# - la asistencia es mayor o igual que `80`
#
# El programa debe mostrar la nota final, si está aprobada y, si está suspensa, el motivo principal:
#
# - `nota final insuficiente`
# - `práctica insuficiente`
# - `asistencia insuficiente`
#
# Si hay varios motivos, basta con mostrar uno de ellos.

# %% [markdown]
# ## Ejercicio 11
#
# Escribe un programa que lea el nivel de batería de un móvil, como entero entre `0` y `100`, e imprima un mensaje:
#
# - menor que `20`: `batería baja`
# - entre `20` y `80`: `batería suficiente`
# - mayor que `80`: `batería alta`
#
# Si el número no está entre `0` y `100`, debe mostrar `nivel no válido`.

# %% [markdown]
# ## Ejercicio 12
#
# Escribe un programa que lea una operación de una sola letra y dos números:
#
# - `s`: suma
# - `r`: resta
# - `m`: multiplicación
# - `d`: división
#
# El programa debe mostrar el resultado. Si la operación es `d` y el segundo número es `0`, debe mostrar `división imposible`. Si la operación no es una de las anteriores, debe mostrar `operación no válida`.
#
# Si la operación se puede realizar, el programa debe indicar también si el resultado es `positivo`, `negativo` o `cero`.
#
# Ejemplo:
#
# ```text
# operación: r
# primer número: 5
# segundo número: 8
# resultado: -3
# signo: negativo
# ```

# %% [markdown]
# ## Ejercicio 13
#
# Usando `for` y `range`, imprime los cuadrados de los números del `1` al `12`, con una línea por número.
#
# La salida debe tener este estilo:
#
# ```text
# 1 -> 1
# 2 -> 4
# 3 -> 9
# ...
# ```

# %% [markdown]
# ## Ejercicio 14
#
# Dada la lista:
#
# ```python
# alturas = [168, 172, 181, 159, 176, 164]
# ```
#
# Recórrela con un `for` y calcula:
#
# - cuántas alturas son mayores o iguales que `170`
# - la altura mayor
# - la altura menor
# - la media de altura
#
# No uses `max()`, `min()` ni `sum()`.

# %% [markdown]
# ## Ejercicio 15
#
# Dada la lista:
#
# ```python
# gastos = [12.50, 7.25, 31.00, 4.75, 18.20]
# ```
#
# Recórrela con un `for` y calcula:
#
# - el gasto total
# - cuántos gastos son mayores que `10`
# - cuál ha sido el gasto más alto
# - si el gasto total supera `70` euros
#
# No uses `sum()`, `max()` ni `min()`.

# %% [markdown]
# ## Ejercicio 16
#
# Usando bucles `for` anidados, imprime todas las parejas posibles entre estas dos listas:
#
# ```python
# colores = ['rojo', 'verde', 'azul']
# tallas = ['S', 'M', 'L']
# ```
#
# La salida debe tener este estilo:
#
# ```text
# rojo - S
# rojo - M
# rojo - L
# verde - S
# ...
# ```

# %% [markdown]
# ## Ejercicio 17
#
# Usando `while`, escribe un programa que lea un entero positivo `n` y calcule:
#
# - la suma de los números desde `1` hasta `n`
# - la suma de los números pares desde `1` hasta `n`
# - la suma de los números impares desde `1` hasta `n`
#
# Ejemplo:
#
# ```text
# n: 5
# suma total: 15
# suma pares: 6
# suma impares: 9
# ```

# %% [markdown]
# ## Ejercicio 18
#
# Usando `while`, escribe un programa que lea un entero `n`. Si `n` es negativo, debe volver a pedirlo hasta que el usuario introduzca un número mayor o igual que `0`. Después debe calcular su factorial.
#
# Recuerda que el factorial de `0` es `1`.
#
# Ejemplo:
#
# ```text
# n: -3
# n: -1
# n: 5
# factorial: 120
# ```

# %% [markdown]
# ## Ejercicio 19
#
# Usando `while`, escribe un programa que pida un PIN hasta que el usuario escriba `2468`. Cuando acierte, debe mostrar `PIN correcto`.

# %% [markdown]
# ## Ejercicio 20
#
# Usando `while`, escribe un programa que simule la carga de una batería. El programa debe leer el porcentaje inicial y un incremento.
#
# Condiciones:
#
# - si el porcentaje inicial es menor que `0`, debe tratarse como `0`
# - si el porcentaje inicial es mayor que `100`, debe tratarse como `100`
# - el incremento debe ser positivo; si no lo es, debe volver a pedirse hasta que sea positivo
#
# Después debe mostrar los porcentajes de carga hasta llegar a `100` y también cuántos pasos de carga se han realizado.
#
# Ejemplo:
#
# ```text
# porcentaje inicial: 35
# incremento: 20
# 35
# 55
# 75
# 95
# 100
# pasos: 4
# ```

# %% [markdown]
# ## Ejercicio 21
#
# Usando `while`, escribe un programa que lea temperaturas hasta que el usuario escriba `fin`. Al terminar, debe mostrar:
#
# - cuántas temperaturas se han introducido
# - la media
# - la temperatura máxima
# - la temperatura mínima
# - cuántas temperaturas han sido mayores o iguales que `30`
#
# Puedes suponer que el usuario introducirá al menos una temperatura antes de escribir `fin`.
#
# No uses `max()`, `min()` ni `sum()`.
#
# Ejemplo:
#
# ```text
# temperatura o fin: 18.5
# temperatura o fin: 31
# temperatura o fin: 20.5
# temperatura o fin: fin
# cantidad: 3
# media: 23.333333333333332
# máxima: 31.0
# mínima: 18.5
# temperaturas altas: 1
# ```

# %% [markdown]
# ## Ejercicio 22
#
# Usando `while`, escribe un programa que lea una frase y la recorra usando un índice. El programa debe contar:
#
# - cuántos espacios contiene
# - cuántas letras `a` contiene
# - cuántos caracteres no son espacios
#
# Ejemplo:
#
# ```text
# frase: aprender python paso a paso
# espacios: 4
# letras a: 4
# caracteres sin espacios: 23
# ```

# %% [markdown]
# ## Ejercicio 23
#
# Escribe un programa que lea una palabra y construya dos nuevas cadenas usando un bucle:
#
# - una cadena con los caracteres en posiciones pares: `0`, `2`, `4`, etc.
# - una cadena con los caracteres en posiciones impares: `1`, `3`, `5`, etc.
#
# Después debe indicar cuál de las dos cadenas es más larga, o si tienen la misma longitud.
#
# Ejemplo:
#
# ```text
# palabra: ordenador
# posiciones pares: odndr
# posiciones impares: reaor
# misma longitud
# ```

# %% [markdown]
# ## Ejercicio 24
#
# Escribe un programa que lea números enteros hasta que el usuario escriba `fin`. El programa debe mostrar:
#
# - el mayor número introducido
# - el menor número introducido
# - cuántos números se han introducido
# - la media de los números introducidos
#
# Puedes suponer que el usuario introducirá al menos un número antes de escribir `fin`. No uses `max()`, `min()` ni `sum()`.
#
# Ejemplo:
#
# ```text
# número o fin: 12
# número o fin: 7
# número o fin: 25
# número o fin: fin
# mayor: 25
# menor: 7
# cantidad: 3
# media: 14.666666666666666
# ```
